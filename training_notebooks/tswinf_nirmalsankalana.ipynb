# %%
import pandas as pd
from dataset import prepare_dataloaders, tswin_train_transform
train_loader, val_loader, test_loader =  prepare_dataloaders('data', tswin_train_transform, batch_size=16, num_workers=4, val_split=0.2, test_split=0)

# %%
from train import main
model = main(train_loader, val_loader, 5, 'models/tswinf_nirmal.pth')
# Out:
# [2025-05-02 21:13:44 CSWin_BOAT_64_24322_small_224](train.py 83): INFO Creating model:cswin_boat/CSWin_BOAT_64_24322_small_224
# [2025-05-02 21:13:46 CSWin_BOAT_64_24322_small_224](train.py 92): INFO number of params: 54765997
# [2025-05-02 21:13:46 CSWin_BOAT_64_24322_small_224](train.py 113): INFO Start training
# [2025-05-02 21:14:27 CSWin_BOAT_64_24322_small_224](train.py 217): INFO Train: [0/35]	eta 0:00:00 lr 0.000041	time 0.2725 (0.3225)	loss 1.6226 (1.6041)	grad_norm 2.2407 (1.4118)	mem 5093MB
# [2025-05-02 21:14:27 CSWin_BOAT_64_24322_small_224](train.py 233): INFO EPOCH 0 training takes 0:00:40
# [2025-05-02 21:14:31 CSWin_BOAT_64_24322_small_224](train.py 321): INFO TEST:	Time 0.223 (0.121)	Loss 1.5932 (1.5968)	Acc@1 25.000 (20.437)	Acc@5 100.000 (100.000)	Mem 5093MB
# [2025-05-02 21:14:31 CSWin_BOAT_64_24322_small_224](train.py 329): INFO  * Acc@1 20.437 Acc@5 100.000
# [2025-05-02 21:14:31 CSWin_BOAT_64_24322_small_224](train.py 333): INFO
# Classification Report:
# ...
